# %%
# !pip install pysus
# !pip install geopandas
# Out:
# Requirement already satisfied: pysus in /usr/local/lib/python3.10/dist-packages (0.9.4)
# Requirement already satisfied: Unidecode<2.0.0,>=1.3.6 in /usr/local/lib/python3.10/dist-packages (from pysus) (1.3.7)
# Requirement already satisfied: cffi==1.15.1 in /usr/local/lib/python3.10/dist-packages (from pysus) (1.15.1)
# Requirement already satisfied: dbfread==2.0.7 in /usr/local/lib/python3.10/dist-packages (from pysus) (2.0.7)
# Requirement already satisfied: elasticsearch==7.16.2 in /usr/local/lib/python3.10/dist-packages (from pysus) (7.16.2)
# Requirement already satisfied: fastparquet<0.9.0,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from pysus) (0.8.3)
# Requirement already satisfied: geobr<0.3.0,>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from pysus) (0.2.0)
# Requirement already satisfied: geocoder<2.0.0,>=1.38.1 in /usr/local/lib/python3.10/dist-packages (from pysus) (1.38.1)
# Requirement already satisfied: ipykernel<7.0.0,>=6.22.0 in /usr/local/lib/python3.10/dist-packages (from pysus) (6.26.0)
# Requirement already satisfied: jupyterlab<4.0.0,>=3.4.5 in /usr/local/lib/python3.10/dist-packages (from pysus) (3.6.6)
# Requirement already satisfied: loguru<0.7.0,>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pysus) (0.6.0)
# Requirement already satisfied: numpy==1.23.2 in /usr/local/lib/python3.10/dist-packages (from pysus) (1.23.2)
# Requirement already satisfied: pyarrow>=11.0.0 in /usr/local/lib/python3.10/dist-packages (from pysus) (14.0.1)
# Requirement already satisfied: pycparser==2.21 in /usr/local/lib/python3.10/dist-packages (from pysus) (2.21)
# Requirement already satisfied: pyreaddbc==1.0.0 in /usr/local/lib/python3.10/dist-packages (from pysus) (1.0.0)
# Requirement already satisfied: python-dateutil==2.8.2 in /usr/local/lib/python3.10/dist-packages (from pysus) (2.8.2)
# Requirement already satisfied: pytz==2022.2.1 in /usr/local/lib/python3.10/dist-packages (from pysus) (2022.2.1)
# Requirement already satisfied: six==1.16.0 in /usr/local/lib/python3.10/dist-packages (from pysus) (1.16.0)
# Requirement already satisfied: tqdm==4.64.0 in /usr/local/lib/python3.10/dist-packages (from pysus) (4.64.0)
# Requirement already satisfied: wget<4.0,>=3.2 in /usr/local/lib/python3.10/dist-packages (from pysus) (3.2)
# Requirement already satisfied: urllib3<2,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from elasticsearch==7.16.2->pysus) (1.26.18)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from elasticsearch==7.16.2->pysus) (2023.7.22)
# Requirement already satisfied: pandas<2.0.0,>=1.4.3 in /usr/local/lib/python3.10/dist-packages (from pyreaddbc==1.0.0->pysus) (1.5.3)
# Requirement already satisfied: cramjam>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from fastparquet<0.9.0,>=0.8.1->pysus) (2.7.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from fastparquet<0.9.0,>=0.8.1->pysus) (2023.6.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from fastparquet<0.9.0,>=0.8.1->pysus) (23.2)
# Requirement already satisfied: geopandas<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from geobr<0.3.0,>=0.2.0->pysus) (0.7.0)
# Requirement already satisfied: shapely<2.0.0,>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from geobr<0.3.0,>=0.2.0->pysus) (1.8.5.post1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from geocoder<2.0.0,>=1.38.1->pysus) (8.1.7)
# Requirement already satisfied: future in /usr/local/lib/python3.10/dist-packages (from geocoder<2.0.0,>=1.38.1->pysus) (0.18.3)
# Requirement already satisfied: ratelim in /usr/local/lib/python3.10/dist-packages (from geocoder<2.0.0,>=1.38.1->pysus) (0.1.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from geocoder<2.0.0,>=1.38.1->pysus) (2.31.0)
# Requirement already satisfied: comm>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from ipykernel<7.0.0,>=6.22.0->pysus) (0.2.0)
# Requirement already satisfied: debugpy>=1.6.5 in /usr/local/lib/python3.10/dist-packages (from ipykernel<7.0.0,>=6.22.0->pysus) (1.6.6)
# Requirement already satisfied: ipython>=7.23.1 in /usr/local/lib/python3.10/dist-packages (from ipykernel<7.0.0,>=6.22.0->pysus) (7.34.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.10/dist-packages (from ipykernel<7.0.0,>=6.22.0->pysus) (6.1.12)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.10/dist-packages (from ipykernel<7.0.0,>=6.22.0->pysus) (5.5.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.10/dist-packages (from ipykernel<7.0.0,>=6.22.0->pysus) (0.1.6)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.10/dist-packages (from ipykernel<7.0.0,>=6.22.0->pysus) (1.5.8)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from ipykernel<7.0.0,>=6.22.0->pysus) (5.9.5)
# Requirement already satisfied: pyzmq>=20 in /usr/local/lib/python3.10/dist-packages (from ipykernel<7.0.0,>=6.22.0->pysus) (23.2.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.10/dist-packages (from ipykernel<7.0.0,>=6.22.0->pysus) (6.3.2)
# Requirement already satisfied: traitlets>=5.4.0 in /usr/local/lib/python3.10/dist-packages (from ipykernel<7.0.0,>=6.22.0->pysus) (5.7.1)
# Requirement already satisfied: jupyterlab-server~=2.19 in /usr/local/lib/python3.10/dist-packages (from jupyterlab<4.0.0,>=3.4.5->pysus) (2.25.2)
# Requirement already satisfied: jupyter-server<3,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from jupyterlab<4.0.0,>=3.4.5->pysus) (1.24.0)
# Requirement already satisfied: jupyter-ydoc~=0.2.4 in /usr/local/lib/python3.10/dist-packages (from jupyterlab<4.0.0,>=3.4.5->pysus) (0.2.5)
# Requirement already satisfied: jupyter-server-ydoc~=0.8.0 in /usr/local/lib/python3.10/dist-packages (from jupyterlab<4.0.0,>=3.4.5->pysus) (0.8.0)
# Requirement already satisfied: nbclassic in /usr/local/lib/python3.10/dist-packages (from jupyterlab<4.0.0,>=3.4.5->pysus) (1.0.0)
# Requirement already satisfied: notebook<7 in /usr/local/lib/python3.10/dist-packages (from jupyterlab<4.0.0,>=3.4.5->pysus) (6.5.5)
# Requirement already satisfied: jinja2>=2.1 in /usr/local/lib/python3.10/dist-packages (from jupyterlab<4.0.0,>=3.4.5->pysus) (3.1.2)
# Requirement already satisfied: tomli in /usr/local/lib/python3.10/dist-packages (from jupyterlab<4.0.0,>=3.4.5->pysus) (2.0.1)
# Requirement already satisfied: fiona in /usr/local/lib/python3.10/dist-packages (from geopandas<0.8.0,>=0.7.0->geobr<0.3.0,>=0.2.0->pysus) (1.9.5)
# Requirement already satisfied: pyproj>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from geopandas<0.8.0,>=0.7.0->geobr<0.3.0,>=0.2.0->pysus) (3.6.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.22.0->pysus) (67.7.2)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.22.0->pysus) (0.19.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.22.0->pysus) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.22.0->pysus) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.22.0->pysus) (3.0.41)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.22.0->pysus) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.22.0->pysus) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.22.0->pysus) (4.8.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.1->jupyterlab<4.0.0,>=3.4.5->pysus) (2.1.3)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel<7.0.0,>=6.22.0->pysus) (4.0.0)
# Requirement already satisfied: anyio<4,>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=1.16.0->jupyterlab<4.0.0,>=3.4.5->pysus) (3.7.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=1.16.0->jupyterlab<4.0.0,>=3.4.5->pysus) (23.1.0)
# Requirement already satisfied: nbconvert>=6.4.4 in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=1.16.0->jupyterlab<4.0.0,>=3.4.5->pysus) (6.5.4)
# Requirement already satisfied: nbformat>=5.2.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=1.16.0->jupyterlab<4.0.0,>=3.4.5->pysus) (5.9.2)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=1.16.0->jupyterlab<4.0.0,>=3.4.5->pysus) (0.18.0)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=1.16.0->jupyterlab<4.0.0,>=3.4.5->pysus) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=1.16.0->jupyterlab<4.0.0,>=3.4.5->pysus) (0.18.0)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=1.16.0->jupyterlab<4.0.0,>=3.4.5->pysus) (1.6.4)
# Requirement already satisfied: jupyter-server-fileid<1,>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-server-ydoc~=0.8.0->jupyterlab<4.0.0,>=3.4.5->pysus) (0.9.0)
# Requirement already satisfied: ypy-websocket<0.9.0,>=0.8.2 in /usr/local/lib/python3.10/dist-packages (from jupyter-server-ydoc~=0.8.0->jupyterlab<4.0.0,>=3.4.5->pysus) (0.8.4)
# Requirement already satisfied: y-py<0.7.0,>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-ydoc~=0.2.4->jupyterlab<4.0.0,>=3.4.5->pysus) (0.6.2)
# Requirement already satisfied: babel>=2.10 in /usr/local/lib/python3.10/dist-packages (from jupyterlab-server~=2.19->jupyterlab<4.0.0,>=3.4.5->pysus) (2.13.1)
# Requirement already satisfied: json5>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from jupyterlab-server~=2.19->jupyterlab<4.0.0,>=3.4.5->pysus) (0.9.14)
# Requirement already satisfied: jsonschema>=4.18.0 in /usr/local/lib/python3.10/dist-packages (from jupyterlab-server~=2.19->jupyterlab<4.0.0,>=3.4.5->pysus) (4.19.2)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.10/dist-packages (from notebook<7->jupyterlab<4.0.0,>=3.4.5->pysus) (0.2.0)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.10/dist-packages (from nbclassic->jupyterlab<4.0.0,>=3.4.5->pysus) (0.2.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->geocoder<2.0.0,>=1.38.1->pysus) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->geocoder<2.0.0,>=1.38.1->pysus) (3.4)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server<3,>=1.16.0->jupyterlab<4.0.0,>=3.4.5->pysus) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server<3,>=1.16.0->jupyterlab<4.0.0,>=3.4.5->pysus) (1.1.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel<7.0.0,>=6.22.0->pysus) (0.8.3)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=4.18.0->jupyterlab-server~=2.19->jupyterlab<4.0.0,>=3.4.5->pysus) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=4.18.0->jupyterlab-server~=2.19->jupyterlab<4.0.0,>=3.4.5->pysus) (2023.11.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=4.18.0->jupyterlab-server~=2.19->jupyterlab<4.0.0,>=3.4.5->pysus) (0.31.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=4.18.0->jupyterlab-server~=2.19->jupyterlab<4.0.0,>=3.4.5->pysus) (0.13.0)
# Requirement already satisfied: jupyter-events>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-server-fileid<1,>=0.6.0->jupyter-server-ydoc~=0.8.0->jupyterlab<4.0.0,>=3.4.5->pysus) (0.9.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab<4.0.0,>=3.4.5->pysus) (4.9.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab<4.0.0,>=3.4.5->pysus) (4.11.2)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab<4.0.0,>=3.4.5->pysus) (6.1.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab<4.0.0,>=3.4.5->pysus) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab<4.0.0,>=3.4.5->pysus) (0.4)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab<4.0.0,>=3.4.5->pysus) (0.2.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab<4.0.0,>=3.4.5->pysus) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab<4.0.0,>=3.4.5->pysus) (0.9.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab<4.0.0,>=3.4.5->pysus) (1.5.0)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab<4.0.0,>=3.4.5->pysus) (1.2.1)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.10/dist-packages (from nbformat>=5.2.0->jupyter-server<3,>=1.16.0->jupyterlab<4.0.0,>=3.4.5->pysus) (2.19.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel<7.0.0,>=6.22.0->pysus) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.23.1->ipykernel<7.0.0,>=6.22.0->pysus) (0.2.10)
# Requirement already satisfied: aiofiles<23,>=22.1.0 in /usr/local/lib/python3.10/dist-packages (from ypy-websocket<0.9.0,>=0.8.2->jupyter-server-ydoc~=0.8.0->jupyterlab<4.0.0,>=3.4.5->pysus) (22.1.0)
# Requirement already satisfied: aiosqlite<1,>=0.17.0 in /usr/local/lib/python3.10/dist-packages (from ypy-websocket<0.9.0,>=0.8.2->jupyter-server-ydoc~=0.8.0->jupyterlab<4.0.0,>=3.4.5->pysus) (0.19.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->jupyter-server<3,>=1.16.0->jupyterlab<4.0.0,>=3.4.5->pysus) (21.2.0)
# Requirement already satisfied: click-plugins>=1.0 in /usr/local/lib/python3.10/dist-packages (from fiona->geopandas<0.8.0,>=0.7.0->geobr<0.3.0,>=0.2.0->pysus) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.10/dist-packages (from fiona->geopandas<0.8.0,>=0.7.0->geobr<0.3.0,>=0.2.0->pysus) (0.7.2)
# Requirement already satisfied: python-json-logger>=2.0.4 in /usr/local/lib/python3.10/dist-packages (from jupyter-events>=0.5.0->jupyter-server-fileid<1,>=0.6.0->jupyter-server-ydoc~=0.8.0->jupyterlab<4.0.0,>=3.4.5->pysus) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in /usr/local/lib/python3.10/dist-packages (from jupyter-events>=0.5.0->jupyter-server-fileid<1,>=0.6.0->jupyter-server-ydoc~=0.8.0->jupyterlab<4.0.0,>=3.4.5->pysus) (6.0.1)
# Requirement already satisfied: rfc3339-validator in /usr/local/lib/python3.10/dist-packages (from jupyter-events>=0.5.0->jupyter-server-fileid<1,>=0.6.0->jupyter-server-ydoc~=0.8.0->jupyterlab<4.0.0,>=3.4.5->pysus) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from jupyter-events>=0.5.0->jupyter-server-fileid<1,>=0.6.0->jupyter-server-ydoc~=0.8.0->jupyterlab<4.0.0,>=3.4.5->pysus) (0.1.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab<4.0.0,>=3.4.5->pysus) (2.5)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab<4.0.0,>=3.4.5->pysus) (0.5.1)
# Requirement already satisfied: fqdn in /usr/local/lib/python3.10/dist-packages (from jsonschema>=4.18.0->jupyterlab-server~=2.19->jupyterlab<4.0.0,>=3.4.5->pysus) (1.5.1)
# Requirement already satisfied: isoduration in /usr/local/lib/python3.10/dist-packages (from jsonschema>=4.18.0->jupyterlab-server~=2.19->jupyterlab<4.0.0,>=3.4.5->pysus) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=4.18.0->jupyterlab-server~=2.19->jupyterlab<4.0.0,>=3.4.5->pysus) (2.4)
# Requirement already satisfied: uri-template in /usr/local/lib/python3.10/dist-packages (from jsonschema>=4.18.0->jupyterlab-server~=2.19->jupyterlab<4.0.0,>=3.4.5->pysus) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=4.18.0->jupyterlab-server~=2.19->jupyterlab<4.0.0,>=3.4.5->pysus) (1.13)
# Requirement already satisfied: arrow>=0.15.0 in /usr/local/lib/python3.10/dist-packages (from isoduration->jsonschema>=4.18.0->jupyterlab-server~=2.19->jupyterlab<4.0.0,>=3.4.5->pysus) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /usr/local/lib/python3.10/dist-packages (from arrow>=0.15.0->isoduration->jsonschema>=4.18.0->jupyterlab-server~=2.19->jupyterlab<4.0.0,>=3.4.5->pysus) (2.8.19.14)
# Requirement already satisfied: geopandas in /usr/local/lib/python3.10/dist-packages (0.7.0)
# Requirement already satisfied: pandas>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from geopandas) (1.5.3)
# Requirement already satisfied: shapely in /usr/local/lib/python3.10/dist-packages (from geopandas) (1.8.5.post1)
# Requirement already satisfied: fiona in /usr/local/lib/python3.10/dist-packages (from geopandas) (1.9.5)
# Requirement already satisfied: pyproj>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from geopandas) (3.6.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.23.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.23.0->geopandas) (2022.2.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.23.0->geopandas) (1.23.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from pyproj>=2.2.0->geopandas) (2023.7.22)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from fiona->geopandas) (23.1.0)
# Requirement already satisfied: click~=8.0 in /usr/local/lib/python3.10/dist-packages (from fiona->geopandas) (8.1.7)
# Requirement already satisfied: click-plugins>=1.0 in /usr/local/lib/python3.10/dist-packages (from fiona->geopandas) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.10/dist-packages (from fiona->geopandas) (0.7.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from fiona->geopandas) (1.16.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from fiona->geopandas) (67.7.2)

# %%
from pysus.online_data.SIA import download, show_datatypes
import pandas as pd
import numpy as np

dataFrame = pd.DataFrame()

ano = 2010
while ano <= 2021:
  mes = 1
  while mes <= 12:
    pa_rs = download('RS', 2020, 12, group='PA')
    df_mensal = pd.read_parquet(pa_rs)

    # Limit data to 500 rows per month
    if df_mensal.shape[0] > 4000:
        df_mensal = df_mensal.sample(4000, random_state=np.random.randint(1, 10000))

    dataFrame = pd.concat([dataFrame, df_mensal], axis=0)  # Concatenate DataFrames

    mes = mes + 1

  print("banco de " + str(ano) + " de " + str('RS') + " baixado e tratado! " + str(dataFrame.shape[0]) + " rows")
  ano = ano + 1


# Remove valores faltantes e duplicados
dataFrame.drop_duplicates()

print(dataFrame.info())
# Out:
# banco de 2010 de RS baixado e tratado! 48000 rows
# banco de 2011 de RS baixado e tratado! 96000 rows
# banco de 2012 de RS baixado e tratado! 144000 rows
# banco de 2013 de RS baixado e tratado! 192000 rows
# banco de 2014 de RS baixado e tratado! 240000 rows
# banco de 2015 de RS baixado e tratado! 288000 rows
# banco de 2016 de RS baixado e tratado! 336000 rows
# banco de 2017 de RS baixado e tratado! 384000 rows
# banco de 2018 de RS baixado e tratado! 432000 rows
# banco de 2019 de RS baixado e tratado! 480000 rows
# banco de 2020 de RS baixado e tratado! 528000 rows
# banco de 2021 de RS baixado e tratado! 576000 rows
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 576000 entries, 29582 to 129431
# Data columns (total 60 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   PA_CODUNI   576000 non-null  object
#  1   PA_GESTAO   576000 non-null  object
#  2   PA_CONDIC   576000 non-null  object
#  3   PA_UFMUN    576000 non-null  object
#  4   PA_REGCT    576000 non-null  object
#  5   PA_INCOUT   576000 non-null  object
#  6   PA_INCURG   576000 non-null  object
#  7   PA_TPUPS    576000 non-null  object
#  8   PA_TIPPRE   576000 non-null  object
#  9   PA_MN_IND   576000 non-null  object
#  10  PA_CNPJCPF  576000 non-null  object
#  11  PA_CNPJMNT  576000 non-null  object
#  12  PA_CNPJ_CC  576000 non-null  object
#  13  PA_MVM      576000 non-null  object
#  14  PA_CMP      576000 non-null  object
#  15  PA_PROC_ID  576000 non-null  object
#  16  PA_TPFIN    576000 non-null  object
#  17  PA_SUBFIN   576000 non-null  object
#  18  PA_NIVCPL   576000 non-null  object
#  19  PA_DOCORIG  576000 non-null  object
#  20  PA_AUTORIZ  576000 non-null  object
#  21  PA_CNSMED   576000 non-null  object
#  22  PA_CBOCOD   576000 non-null  object
#  23  PA_MOTSAI   576000 non-null  object
#  24  PA_OBITO    576000 non-null  object
#  25  PA_ENCERR   576000 non-null  object
#  26  PA_PERMAN   576000 non-null  object
#  27  PA_ALTA     576000 non-null  object
#  28  PA_TRANSF   576000 non-null  object
#  29  PA_CIDPRI   576000 non-null  object
#  30  PA_CIDSEC   576000 non-null  object
#  31  PA_CIDCAS   576000 non-null  object
#  32  PA_CATEND   576000 non-null  object
#  33  PA_IDADE    576000 non-null  object
#  34  IDADEMIN    576000 non-null  object
#  35  IDADEMAX    576000 non-null  object
#  36  PA_FLIDADE  576000 non-null  object
#  37  PA_SEXO     576000 non-null  object
#  38  PA_RACACOR  576000 non-null  object
#  39  PA_MUNPCN   576000 non-null  object
#  40  PA_QTDPRO   576000 non-null  object
#  41  PA_QTDAPR   576000 non-null  object
#  42  PA_VALPRO   576000 non-null  object
#  43  PA_VALAPR   576000 non-null  object
#  44  PA_UFDIF    576000 non-null  object
#  45  PA_MNDIF    576000 non-null  object
#  46  PA_DIF_VAL  576000 non-null  object
#  47  NU_VPA_TOT  576000 non-null  object
#  48  NU_PA_TOT   576000 non-null  object
#  49  PA_INDICA   576000 non-null  object
#  50  PA_CODOCO   576000 non-null  object
#  51  PA_FLQT     576000 non-null  object
#  52  PA_FLER     576000 non-null  object
#  53  PA_ETNIA    576000 non-null  object
#  54  PA_VL_CF    576000 non-null  object
#  55  PA_VL_CL    576000 non-null  object
#  56  PA_VL_INC   576000 non-null  object
#  57  PA_SRV_C    576000 non-null  object
#  58  PA_INE      576000 non-null  object
#  59  PA_NAT_JUR  576000 non-null  object
# dtypes: object(60)
# memory usage: 268.1+ MB
# None

# %%
# Mantém apenas colunas que for usar
columns = ['PA_UFMUN','PA_REGCT','PA_IDADE','PA_SEXO','PA_QTDPRO','PA_QTDAPR','PA_VALPRO','PA_VALAPR']
dataFrame = dataFrame.drop(columns=list(set(dataFrame.columns) - set(columns)))

print(dataFrame.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 576000 entries, 29582 to 129431
# Data columns (total 8 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   PA_UFMUN   576000 non-null  object
#  1   PA_REGCT   576000 non-null  object
#  2   PA_IDADE   576000 non-null  object
#  3   PA_SEXO    576000 non-null  object
#  4   PA_QTDPRO  576000 non-null  object
#  5   PA_QTDAPR  576000 non-null  object
#  6   PA_VALPRO  576000 non-null  object
#  7   PA_VALAPR  576000 non-null  object
# dtypes: object(8)
# memory usage: 39.6+ MB
# None

# %%
# Tratamento dados para float e inteiro
dataFrame['PA_VALPRO'] = dataFrame['PA_VALPRO'].str.strip().astype(float)
dataFrame['PA_VALAPR'] = dataFrame['PA_VALAPR'].str.strip().astype(float)
dataFrame['PA_QTDAPR'] = dataFrame['PA_QTDAPR'].str.strip().astype(int)
dataFrame['PA_QTDPRO'] = dataFrame['PA_QTDPRO'].str.strip().astype(int)
dataFrame['PA_IDADE'] = dataFrame['PA_IDADE'].str.strip().astype(int)
dataFrame
# Out:
#        PA_UFMUN PA_REGCT  PA_IDADE PA_SEXO  PA_QTDPRO  PA_QTDAPR  PA_VALPRO  \
# 29582    432300     0000        43       0          1          1       0.00
# 293786   431490     7113        65       M          1          1      12.47
# 172086   431390     0000        32       M          1          1      17.67
# 292025   431990     0000        59       M          1          1       0.00
# 234733   431140     0000        68       F          1          1       4.67
# ...         ...      ...       ...     ...        ...        ...        ...
# 222049   431490     7101        78       M          1          1      24.24
# 180045   431490     0000        55       F          1          1      15.59
# 174805   432000     0000       999       0        113        113       0.00
# 61608    431405     0000        59       F          1          1       0.00
# 129431   432170     0000        44       M          1          1       0.00
#
#         PA_VALAPR
# 29582        0.00
# 293786      12.47
# 172086      17.67
# 292025       0.00
# 234733       4.67
# ...           ...
# 222049      24.24
# 180045      15.59
# 174805       0.00
# 61608        0.00
# 129431       0.00
#
# [576000 rows x 8 columns]

# %%
# Conversão e donwload
dataFrame.to_csv('SIA_dataframe.csv')
